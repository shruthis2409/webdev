# %% [markdown]
# FACE DETECTION with python using OPEN CV

# %%
import cv2

# %%
pip install Cascade
# Out:
# Requirement already satisfied: Cascade in /usr/local/lib/python3.10/dist-packages (0.1)
# Requirement already satisfied: progressbar in /usr/local/lib/python3.10/dist-packages (from Cascade) (2.5)
# Requirement already satisfied: imaplib2 in /usr/local/lib/python3.10/dist-packages (from Cascade) (3.6)

# %%
face_cascade = cv2.CascadeClassifier('face_detector.xml')

# %%
img = cv2.imread('photo.jpg')

# %%
faces= face_cascade.detectMultiScale(img,1.1,4)

# %%
for(x,y,w,h) in faces:
  cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)

# %%
cv2.imwrite('photodetected.jpg',img)
print("SUCCESSFULLY DETECTED")
# Out:
# SUCCESSFULLY DETECTED
